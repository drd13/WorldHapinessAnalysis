# %% [markdown]
# # Exploratory analysis US deaths

# %% [markdown]
# We start by loading all the modules that are required

# %%
import pandas as pd
import pytrends

# %%
from pytrends.request import TrendReq
pytrends = TrendReq(hl='en-US', tz=360)
kw_list = ["Blockchain"]
pytrends.build_payload(kw_list, cat=0, timeframe='today 5-y', geo='', gprop='')
pytrends.get_historical_interest(kw_list, year_start=2018, month_start=1, day_start=1, hour_start=0, year_end=2018, month_end=2, day_end=1, hour_end=0, cat=0, geo='', gprop='', sleep=0)
# Out:
#                      Blockchain  isPartial
# date
# 2018-01-01 00:00:00          40      False
# 2018-01-01 01:00:00          38      False
# 2018-01-01 02:00:00          41      False
# 2018-01-01 03:00:00          40      False
# 2018-01-01 04:00:00          38      False
# 2018-01-01 05:00:00          40      False
# 2018-01-01 06:00:00          44      False
# 2018-01-01 07:00:00          41      False
# 2018-01-01 08:00:00          45      False
# 2018-01-01 09:00:00          44      False
# 2018-01-01 10:00:00          47      False
# 2018-01-01 11:00:00          45      False
# 2018-01-01 12:00:00          45      False
# 2018-01-01 13:00:00          46      False
# 2018-01-01 14:00:00          45      False
# 2018-01-01 15:00:00          44      False
# 2018-01-01 16:00:00          45      False
# 2018-01-01 17:00:00          45      False
# 2018-01-01 18:00:00          47      False
# 2018-01-01 19:00:00          51      False
# 2018-01-01 20:00:00          51      False
# 2018-01-01 21:00:00          52      False
# 2018-01-01 22:00:00          57      False
# 2018-01-01 23:00:00          66      False
# 2018-01-02 00:00:00          58      False
# 2018-01-02 01:00:00          58      False
# 2018-01-02 02:00:00          61      False
# 2018-01-02 03:00:00          63      False
# 2018-01-02 04:00:00          69      False
# 2018-01-02 05:00:00          69      False
# ...                         ...        ...
# 2018-01-27 19:00:00          64      False
# 2018-01-27 20:00:00          61      False
# 2018-01-27 21:00:00          65      False
# 2018-01-27 22:00:00          66      False
# 2018-01-27 23:00:00          65      False
# 2018-01-28 00:00:00          64      False
# 2018-01-28 01:00:00          59      False
# 2018-01-28 02:00:00          59      False
# 2018-01-28 03:00:00          62      False
# 2018-01-28 04:00:00          63      False
# 2018-01-28 05:00:00          62      False
# 2018-01-28 06:00:00          66      False
# 2018-01-28 07:00:00          67      False
# 2018-01-28 08:00:00          64      False
# 2018-01-28 09:00:00          62      False
# 2018-01-28 10:00:00          61      False
# 2018-01-28 11:00:00          60      False
# 2018-01-28 12:00:00          60      False
# 2018-01-28 13:00:00          60      False
# 2018-01-28 14:00:00          59      False
# 2018-01-28 15:00:00          60      False
# 2018-01-28 16:00:00          64      False
# 2018-01-28 17:00:00          64      False
# 2018-01-28 18:00:00          81      False
# 2018-01-28 19:00:00          65      False
# 2018-01-28 20:00:00          67      False
# 2018-01-28 21:00:00          69      False
# 2018-01-28 22:00:00          77      False
# 2018-01-28 23:00:00          73      False
# 2018-01-29 00:00:00          76      False
#
# [676 rows x 2 columns]

# %%
df = pd.read_csv("leading_cause_death.csv")

# %%
df
# Out:
#        YEAR                                     113_CAUSE_NAME  \
# 0      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 1      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 2      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 3      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 4      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 5      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 6      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 7      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 8      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 9      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 10     1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 11     1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 12     1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 13     1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 14     1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 15     1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 16     1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 17     1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 18     1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 19     1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 20     1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 21     1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 22     1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 23     1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 24     1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 25     1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 26     1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 27     1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 28     1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 29     1999  Accidents (unintentional injuries) (V01-X59,Y8...
# ...     ...                                                ...
# 13230  2013                               Septicemia (A40-A41)
# 13231  2013                               Septicemia (A40-A41)
# 13232  2013                               Septicemia (A40-A41)
# 13233  2013                               Septicemia (A40-A41)
# 13234  2013                               Septicemia (A40-A41)
# 13235  2013                               Septicemia (A40-A41)
# 13236  2013                               Septicemia (A40-A41)
# 13237  2013                               Septicemia (A40-A41)
# 13238  2013                               Septicemia (A40-A41)
# 13239  2013                               Septicemia (A40-A41)
# 13240  2013                               Septicemia (A40-A41)
# 13241  2013                               Septicemia (A40-A41)
# 13242  2013                               Septicemia (A40-A41)
# 13243  2013                               Septicemia (A40-A41)
# 13244  2013                               Septicemia (A40-A41)
# 13245  2013                               Septicemia (A40-A41)
# 13246  2013                               Septicemia (A40-A41)
# 13247  2013                               Septicemia (A40-A41)
# 13248  2013                               Septicemia (A40-A41)
# 13249  2013                               Septicemia (A40-A41)
# 13250  2013                               Septicemia (A40-A41)
# 13251  2013                               Septicemia (A40-A41)
# 13252  2013                               Septicemia (A40-A41)
# 13253  2013                               Septicemia (A40-A41)
# 13254  2013                               Septicemia (A40-A41)
# 13255  2013                               Septicemia (A40-A41)
# 13256  2013                               Septicemia (A40-A41)
# 13257  2013                               Septicemia (A40-A41)
# 13258  2013                               Septicemia (A40-A41)
# 13259  2013                               Septicemia (A40-A41)
#
#                    CAUSE_NAME                 STATE DEATHS   AADR
# 0      Unintentional Injuries               Alabama   2313  52.17
# 1      Unintentional Injuries                Alaska    294  55.91
# 2      Unintentional Injuries               Arizona   2214  44.79
# 3      Unintentional Injuries              Arkansas   1287  47.56
# 4      Unintentional Injuries            California   9198  28.71
# 5      Unintentional Injuries              Colorado   1519  38.98
# 6      Unintentional Injuries           Connecticut   1034  29.31
# 7      Unintentional Injuries              Delaware    267  35.25
# 8      Unintentional Injuries  District of Columbia    161  28.38
# 9      Unintentional Injuries               Florida   5961  35.73
# 10     Unintentional Injuries               Georgia   3078  41.52
# 11     Unintentional Injuries                Hawaii    293  24.33
# 12     Unintentional Injuries                 Idaho    597  48.32
# 13     Unintentional Injuries              Illinois   4125  33.69
# 14     Unintentional Injuries               Indiana   2309  38.43
# 15     Unintentional Injuries                  Iowa   1123  35.24
# 16     Unintentional Injuries                Kansas   1126  40.68
# 17     Unintentional Injuries              Kentucky   1730  43.29
# 18     Unintentional Injuries             Louisiana   1940  44.66
# 19     Unintentional Injuries                 Maine    458  34.87
# 20     Unintentional Injuries              Maryland   1296  25.93
# 21     Unintentional Injuries         Massachusetts   1303  19.61
# 22     Unintentional Injuries              Michigan   3188  32.75
# 23     Unintentional Injuries             Minnesota   1772  35.75
# 24     Unintentional Injuries           Mississippi   1642  58.85
# 25     Unintentional Injuries              Missouri   2465  43.22
# 26     Unintentional Injuries               Montana    461  50.25
# 27     Unintentional Injuries              Nebraska    668  37.34
# 28     Unintentional Injuries                Nevada    710  38.48
# 29     Unintentional Injuries         New Hampshire    329  27.53
# ...                       ...                   ...    ...    ...
# 13230              Septicemia              Michigan   1215  10.27
# 13231              Septicemia             Minnesota    382   6.08
# 13232              Septicemia           Mississippi    674  20.78
# 13233              Septicemia              Missouri    809  11.24
# 13234              Septicemia               Montana    110   8.69
# 13235              Septicemia              Nebraska    126   5.91
# 13236              Septicemia                Nevada    260   9.11
# 13237              Septicemia         New Hampshire     92   5.70
# 13238              Septicemia            New Jersey   1785  16.96
# 13239              Septicemia            New Mexico    214   9.14
# 13240              Septicemia              New York   2387  10.28
# 13241              Septicemia        North Carolina   1484  13.77
# 13242              Septicemia          North Dakota     72   8.33
# 13243              Septicemia                  Ohio   1741  12.55
# 13244              Septicemia              Oklahoma    504  11.79
# 13245              Septicemia                Oregon    225   4.74
# 13246              Septicemia          Pennsylvania   2234  13.22
# 13247              Septicemia          Rhode Island    105   7.64
# 13248              Septicemia        South Carolina    731  13.60
# 13249              Septicemia          South Dakota     75   7.36
# 13250              Septicemia             Tennessee    841  11.51
# 13251              Septicemia                 Texas   3892  16.45
# 13252              Septicemia         United States  38156  10.73
# 13253              Septicemia                  Utah    158   6.94
# 13254              Septicemia               Vermont     47   5.76
# 13255              Septicemia              Virginia   1475  17.03
# 13256              Septicemia            Washington    453   5.92
# 13257              Septicemia         West Virginia    331  13.92
# 13258              Septicemia             Wisconsin    484   6.93
# 13259              Septicemia               Wyoming     69  10.33
#
# [13260 rows x 6 columns]

# %%
state = df.loc[(df['STATE'] == "Texas") & (df["YEAR"]==2013)]
state
#state["CAUSE_NAME"][12376]
#state["DEATHS"][12376]
# Out:
#        YEAR                                     113_CAUSE_NAME  \
# 12420  2013  Accidents (unintentional injuries) (V01-X59,Y8...
# 12471  2013                                         All Causes
# 12523  2013                          Alzheimer's disease (G30)
# 12575  2013       Assault (homicide) (*U01-*U02,X85-Y09,Y87.1)
# 12627  2013                 Cerebrovascular diseases (I60-I69)
# 12679  2013  Chronic liver disease and cirrhosis (K70,K73-K74)
# 12731  2013       Chronic lower respiratory diseases (J40-J47)
# 12783  2013                        Diabetes mellitus (E10-E14)
# 12835  2013        Diseases of heart (I00-I09,I11,I13,I20-I51)
# 12887  2013  Essential hypertension and hypertensive renal ...
# 12939  2013                  Influenza and pneumonia (J09-J18)
# 12991  2013  Intentional self-harm (suicide) (*U03,X60-X84,...
# 13043  2013                      Malignant neoplasms (C00-C97)
# 13095  2013  Nephritis, nephrotic syndrome and nephrosis (N...
# 13147  2013                      Parkinson's disease (G20-G21)
# 13199  2013        Pneumonitis due to solids and liquids (J69)
# 13251  2013                               Septicemia (A40-A41)
#
#                                               CAUSE_NAME  STATE  DEATHS  \
# 12420                             Unintentional Injuries  Texas    9395
# 12471                                         All Causes  Texas  179183
# 12523                                Alzheimer's disease  Texas    5293
# 12575                                           Homicide  Texas    1354
# 12627                                             Stroke  Texas    9283
# 12679                Chronic liver disease and cirrhosis  Texas    3412
# 12731                                               CLRD  Texas    9800
# 12783                                           Diabetes  Texas    5273
# 12835                                  Diseases of Heart  Texas   40203
# 12887  Essential hypertension and hypertensive renal ...  Texas    1961
# 12939                            Influenza and pneumonia  Texas    3339
# 12991                                            Suicide  Texas    3059
# 13043                                             Cancer  Texas   38412
# 13095                                     Kidney Disease  Texas    3722
# 13147                                Parkinson's disease  Texas    1710
# 13199              Pneumonitis due to solids and liquids  Texas    1274
# 13251                                         Septicemia  Texas    3892
#
#          AADR
# 12420   36.96
# 12471  751.60
# 12523   24.29
# 12575    5.13
# 12627   40.17
# 12679   12.87
# 12731   42.41
# 12783   21.62
# 12835  170.67
# 12887    8.45
# 12939   14.41
# 12991   11.69
# 13043  156.91
# 13095   15.85
# 13147    7.87
# 13199    5.63
# 13251   16.45

# %%
#for row in df.iterrows():
#    print(row)
row[1]["DEATHS"]
# Out:
# '69'

# %% [markdown]
# we take this database and convert into a dictionary for ease of use

# %%
deaths_per_state = {}
states = df.STATE.unique()
for state in states:
    if state in us_state_abbrev:
        deaths_per_state[str(state)]={}
        state_df = df.loc[(df['STATE'] == state) & (df["YEAR"]==2013)]
        for row in state_df.iterrows():
            deaths = row[1]["DEATHS"]
            cause = row[1]["CAUSE_NAME"]
            if deaths == "x":
                deaths = 0
            deaths_per_state[str(state)][cause]=float(deaths)

# %%
for state in deaths_per_state:
    print(state)
    print(deaths_per_state[state]["Suicide"]/deaths_per_state[state]["All Causes"])
# Out:
# Alabama
# 0.014365697662834485
# Michigan
# 0.014013938187169943
# Rhode Island
# 0.013480392156862746
# Colorado
# 0.029870669197911724
# Nebraska
# 0.013964707375904533
# Oklahoma
# 0.017324927052938723
# California
# 0.01620637866958717
# Wyoming
# 0.028565101860053146
# Kentucky
# 0.016019561690166596
# Washington
# 0.020033551810237204
# New Hampshire
# 0.016977149674222262
# New Jersey
# 0.010601795442768512
# Massachusetts
# 0.010482526068869463
# New Mexico
# 0.02564712883070515
# Illinois
# 0.012775505072484792
# Louisiana
# 0.01347353824820892
# West Virginia
# 0.014787346060522823
# Ohio
# 0.013473661904677815
# Maine
# 0.018085184911788586
# Missouri
# 0.016711928138709004
# Vermont
# 0.019861677602411774
# Montana
# 0.02554936389443802
# South Carolina
# 0.015611681844690682
# Idaho
# 0.024770789769985525
# Kansas
# 0.016723066026599512
# North Carolina
# 0.0154088012576654
# Florida
# 0.016166791819426655
# Hawaii
# 0.016277962874821514
# Texas
# 0.017071932047125007
# North Dakota
# 0.020535857532488367
# Georgia
# 0.01614106115491157
# New York
# 0.011178181673612998
# Utah
# 0.035378223145545645
# Maryland
# 0.012453763487929261
# Alaska
# 0.042782086564923695
# Minnesota
# 0.01654183033644814
# Pennsylvania
# 0.013847261913059641
# Indiana
# 0.015547796297516306
# Mississippi
# 0.012637201576393186
# Delaware
# 0.015313166813104054
# Arizona
# 0.02301420825582776
# Tennessee
# 0.0162445194461092
# Arkansas
# 0.016953050563458947
# Connecticut
# 0.011136609071274298
# Wisconsin
# 0.016991164594410905
# Nevada
# 0.025200298118129308
# South Dakota
# 0.020707141850964925
# Oregon
# 0.02056631014467132
# Iowa
# 0.015441481276772143
# Virginia
# 0.017092926844824288

# %%
deaths_per_state
# Out:
# {'Alabama': {'All Causes': 50189.0,
#   "Alzheimer's disease": 1398.0,
#   'CLRD': 3043.0,
#   'Cancer': 10328.0,
#   'Chronic liver disease and cirrhosis': 577.0,
#   'Diabetes': 1349.0,
#   'Diseases of Heart': 12472.0,
#   'Essential hypertension and hypertensive renal disease': 585.0,
#   'Homicide': 417.0,
#   'Influenza and pneumonia': 1035.0,
#   'Kidney Disease': 1057.0,
#   "Parkinson's disease": 425.0,
#   'Pneumonitis due to solids and liquids': 284.0,
#   'Septicemia': 965.0,
#   'Stroke': 2604.0,
#   'Suicide': 721.0,
#   'Unintentional Injuries': 2329.0},
#  'Alaska': {'All Causes': 3997.0,
#   "Alzheimer's disease": 72.0,
#   'CLRD': 197.0,
#   'Cancer': 1016.0,
#   'Chronic liver disease and cirrhosis': 82.0,
#   'Diabetes': 112.0,
#   'Diseases of Heart': 706.0,
#   'Essential hypertension and hypertensive renal disease': 35.0,
#   'Homicide': 43.0,
#   'Influenza and pneumonia': 66.0,
#   'Kidney Disease': 49.0,
#   "Parkinson's disease": 36.0,
#   'Pneumonitis due to solids and liquids': 16.0,
#   'Septicemia': 37.0,
#   'Stroke': 189.0,
#   'Suicide': 171.0,
#   'Unintentional Injuries': 353.0},
#  'Arizona': {'All Causes': 50534.0,
#   "Alzheimer's disease": 2383.0,
#   'CLRD': 3345.0,
#   'Cancer': 11347.0,
#   'Chronic liver disease and cirrhosis': 1069.0,
#   'Diabetes': 1786.0,
#   'Diseases of Heart': 10755.0,
#   'Essential hypertension and hypertensive renal disease': 775.0,
#   'Homicide': 389.0,
#   'Influenza and pneumonia': 776.0,
#   'Kidney Disease': 374.0,
#   "Parkinson's disease": 584.0,
#   'Pneumonitis due to solids and liquids': 260.0,
#   'Septicemia': 370.0,
#   'Stroke': 2162.0,
#   'Suicide': 1163.0,
#   'Unintentional Injuries': 3349.0},
#  'Arkansas': {'All Causes': 30437.0,
#   "Alzheimer's disease": 918.0,
#   'CLRD': 2090.0,
#   'Cancer': 6688.0,
#   'Chronic liver disease and cirrhosis': 338.0,
#   'Diabetes': 835.0,
#   'Diseases of Heart': 7377.0,
#   'Essential hypertension and hypertensive renal disease': 276.0,
#   'Homicide': 212.0,
#   'Influenza and pneumonia': 794.0,
#   'Kidney Disease': 762.0,
#   "Parkinson's disease": 196.0,
#   'Pneumonitis due to solids and liquids': 194.0,
#   'Septicemia': 529.0,
#   'Stroke': 1637.0,
#   'Suicide': 516.0,
#   'Unintentional Injuries': 1373.0},
#  'California': {'All Causes': 248359.0,
#   "Alzheimer's disease": 11891.0,
#   'CLRD': 13598.0,
#   'Cancer': 57714.0,
#   'Chronic liver disease and cirrhosis': 4824.0,
#   'Diabetes': 8057.0,
#   'Diseases of Heart': 60299.0,
#   'Essential hypertension and hypertensive renal disease': 4720.0,
#   'Homicide': 1890.0,
#   'Influenza and pneumonia': 6551.0,
#   'Kidney Disease': 2840.0,
#   "Parkinson's disease": 2543.0,
#   'Pneumonitis due to solids and liquids': 1498.0,
#   'Septicemia': 1310.0,
#   'Stroke': 13698.0,
#   'Suicide': 4025.0,
#   'Unintentional Injuries': 11538.0},
#  'Colorado': {'All Causes': 33712.0,
#   "Alzheimer's disease": 1316.0,
#   'CLRD': 2297.0,
#   'Cancer': 7357.0,
#   'Chronic liver disease and cirrhosis': 712.0,
#   'Diabetes': 788.0,
#   'Diseases of Heart': 6456.0,
#   'Essential hypertension and hypertensive renal disease': 260.0,
#   'Homicide': 184.0,
#   'Influenza and pneumonia': 606.0,
#   'Kidney Disease': 450.0,
#   "Parkinson's disease": 372.0,
#   'Pneumonitis due to solids and liquids': 290.0,
#   'Septicemia': 392.0,
#   'Stroke': 1588.0,
#   'Suicide': 1007.0,
#   'Unintentional Injuries': 2422.0},
#  'Connecticut': {'All Causes': 29632.0,
#   "Alzheimer's disease": 824.0,
#   'CLRD': 1348.0,
#   'Cancer': 6619.0,
#   'Chronic liver disease and cirrhosis': 336.0,
#   'Diabetes': 664.0,
#   'Diseases of Heart': 7090.0,
#   'Essential hypertension and hypertensive renal disease': 374.0,
#   'Homicide': 100.0,
#   'Influenza and pneumonia': 604.0,
#   'Kidney Disease': 565.0,
#   "Parkinson's disease": 279.0,
#   'Pneumonitis due to solids and liquids': 370.0,
#   'Septicemia': 575.0,
#   'Stroke': 1348.0,
#   'Suicide': 330.0,
#   'Unintentional Injuries': 1582.0},
#  'Delaware': {'All Causes': 7967.0,
#   "Alzheimer's disease": 192.0,
#   'CLRD': 482.0,
#   'Cancer': 1905.0,
#   'Chronic liver disease and cirrhosis': 82.0,
#   'Diabetes': 218.0,
#   'Diseases of Heart': 1861.0,
#   'Essential hypertension and hypertensive renal disease': 69.0,
#   'Homicide': 52.0,
#   'Influenza and pneumonia': 150.0,
#   'Kidney Disease': 178.0,
#   "Parkinson's disease": 81.0,
#   'Pneumonitis due to solids and liquids': 51.0,
#   'Septicemia': 157.0,
#   'Stroke': 409.0,
#   'Suicide': 122.0,
#   'Unintentional Injuries': 412.0},
#  'Florida': {'All Causes': 181112.0,
#   "Alzheimer's disease": 5093.0,
#   'CLRD': 11379.0,
#   'Cancer': 42735.0,
#   'Chronic liver disease and cirrhosis': 2668.0,
#   'Diabetes': 5238.0,
#   'Diseases of Heart': 42656.0,
#   'Essential hypertension and hypertensive renal disease': 2147.0,
#   'Homicide': 1150.0,
#   'Influenza and pneumonia': 2662.0,
#   'Kidney Disease': 3130.0,
#   "Parkinson's disease": 1947.0,
#   'Pneumonitis due to solids and liquids': 1016.0,
#   'Septicemia': 2096.0,
#   'Stroke': 8698.0,
#   'Suicide': 2928.0,
#   'Unintentional Injuries': 8736.0},
#  'Georgia': {'All Causes': 75088.0,
#   "Alzheimer's disease": 2048.0,
#   'CLRD': 4172.0,
#   'Cancer': 16417.0,
#   'Chronic liver disease and cirrhosis': 898.0,
#   'Diabetes': 2199.0,
#   'Diseases of Heart': 16550.0,
#   'Essential hypertension and hypertensive renal disease': 1084.0,
#   'Homicide': 641.0,
#   'Influenza and pneumonia': 1494.0,
#   'Kidney Disease': 1652.0,
#   "Parkinson's disease": 631.0,
#   'Pneumonitis due to solids and liquids': 502.0,
#   'Septicemia': 1560.0,
#   'Stroke': 3694.0,
#   'Suicide': 1212.0,
#   'Unintentional Injuries': 3727.0},
#  'Hawaii': {'All Causes': 10505.0,
#   "Alzheimer's disease": 260.0,
#   'CLRD': 279.0,
#   'Cancer': 2332.0,
#   'Chronic liver disease and cirrhosis': 112.0,
#   'Diabetes': 271.0,
#   'Diseases of Heart': 2521.0,
#   'Essential hypertension and hypertensive renal disease': 112.0,
#   'Homicide': 33.0,
#   'Influenza and pneumonia': 457.0,
#   'Kidney Disease': 209.0,
#   "Parkinson's disease": 98.0,
#   'Pneumonitis due to solids and liquids': 110.0,
#   'Septicemia': 149.0,
#   'Stroke': 634.0,
#   'Suicide': 171.0,
#   'Unintentional Injuries': 467.0},
#  'Idaho': {'All Causes': 12434.0,
#   "Alzheimer's disease": 347.0,
#   'CLRD': 808.0,
#   'Cancer': 2707.0,
#   'Chronic liver disease and cirrhosis': 207.0,
#   'Diabetes': 404.0,
#   'Diseases of Heart': 2495.0,
#   'Essential hypertension and hypertensive renal disease': 135.0,
#   'Homicide': 31.0,
#   'Influenza and pneumonia': 259.0,
#   'Kidney Disease': 148.0,
#   "Parkinson's disease": 142.0,
#   'Pneumonitis due to solids and liquids': 91.0,
#   'Septicemia': 100.0,
#   'Stroke': 598.0,
#   'Suicide': 308.0,
#   'Unintentional Injuries': 776.0},
#  'Illinois': {'All Causes': 103401.0,
#   "Alzheimer's disease": 2919.0,
#   'CLRD': 5532.0,
#   'Cancer': 24491.0,
#   'Chronic liver disease and cirrhosis': 1279.0,
#   'Diabetes': 2798.0,
#   'Diseases of Heart': 24839.0,
#   'Essential hypertension and hypertensive renal disease': 1049.0,
#   'Homicide': 792.0,
#   'Influenza and pneumonia': 2441.0,
#   'Kidney Disease': 2444.0,
#   "Parkinson's disease": 1044.0,
#   'Pneumonitis due to solids and liquids': 844.0,
#   'Septicemia': 1697.0,
#   'Stroke': 5294.0,
#   'Suicide': 1321.0,
#   'Unintentional Injuries': 4511.0},
#  'Indiana': {'All Causes': 60716.0,
#   "Alzheimer's disease": 2104.0,
#   'CLRD': 4266.0,
#   'Cancer': 13258.0,
#   'Chronic liver disease and cirrhosis': 752.0,
#   'Diabetes': 1943.0,
#   'Diseases of Heart': 13773.0,
#   'Essential hypertension and hypertensive renal disease': 651.0,
#   'Homicide': 400.0,
#   'Influenza and pneumonia': 1132.0,
#   'Kidney Disease': 1352.0,
#   "Parkinson's disease": 555.0,
#   'Pneumonitis due to solids and liquids': 449.0,
#   'Septicemia': 1024.0,
#   'Stroke': 2996.0,
#   'Suicide': 944.0,
#   'Unintentional Injuries': 2898.0},
#  'Iowa': {'All Causes': 28948.0,
#   "Alzheimer's disease": 1252.0,
#   'CLRD': 1892.0,
#   'Cancer': 6509.0,
#   'Chronic liver disease and cirrhosis': 308.0,
#   'Diabetes': 747.0,
#   'Diseases of Heart': 6995.0,
#   'Essential hypertension and hypertensive renal disease': 324.0,
#   'Homicide': 60.0,
#   'Influenza and pneumonia': 761.0,
#   'Kidney Disease': 369.0,
#   "Parkinson's disease": 359.0,
#   'Pneumonitis due to solids and liquids': 308.0,
#   'Septicemia': 260.0,
#   'Stroke': 1409.0,
#   'Suicide': 447.0,
#   'Unintentional Injuries': 1422.0},
#  'Kansas': {'All Causes': 25414.0,
#   "Alzheimer's disease": 742.0,
#   'CLRD': 1673.0,
#   'Cancer': 5379.0,
#   'Chronic liver disease and cirrhosis': 248.0,
#   'Diabetes': 654.0,
#   'Diseases of Heart': 5364.0,
#   'Essential hypertension and hypertensive renal disease': 218.0,
#   'Homicide': 117.0,
#   'Influenza and pneumonia': 715.0,
#   'Kidney Disease': 594.0,
#   "Parkinson's disease": 307.0,
#   'Pneumonitis due to solids and liquids': 203.0,
#   'Septicemia': 364.0,
#   'Stroke': 1320.0,
#   'Suicide': 425.0,
#   'Unintentional Injuries': 1359.0},
#  'Kentucky': {'All Causes': 43759.0,
#   "Alzheimer's disease": 1462.0,
#   'CLRD': 3187.0,
#   'Cancer': 10085.0,
#   'Chronic liver disease and cirrhosis': 558.0,
#   'Diabetes': 1187.0,
#   'Diseases of Heart': 9971.0,
#   'Essential hypertension and hypertensive renal disease': 319.0,
#   'Homicide': 202.0,
#   'Influenza and pneumonia': 919.0,
#   'Kidney Disease': 991.0,
#   "Parkinson's disease": 337.0,
#   'Pneumonitis due to solids and liquids': 334.0,
#   'Septicemia': 685.0,
#   'Stroke': 1990.0,
#   'Suicide': 701.0,
#   'Unintentional Injuries': 2513.0},
#  'Louisiana': {'All Causes': 43270.0,
#   "Alzheimer's disease": 1505.0,
#   'CLRD': 2274.0,
#   'Cancer': 9419.0,
#   'Chronic liver disease and cirrhosis': 503.0,
#   'Diabetes': 1329.0,
#   'Diseases of Heart': 10346.0,
#   'Essential hypertension and hypertensive renal disease': 454.0,
#   'Homicide': 552.0,
#   'Influenza and pneumonia': 892.0,
#   'Kidney Disease': 1108.0,
#   "Parkinson's disease": 284.0,
#   'Pneumonitis due to solids and liquids': 181.0,
#   'Septicemia': 867.0,
#   'Stroke': 2098.0,
#   'Suicide': 583.0,
#   'Unintentional Injuries': 2333.0},
#  'Maine': {'All Causes': 13547.0,
#   "Alzheimer's disease": 401.0,
#   'CLRD': 902.0,
#   'Cancer': 3227.0,
#   'Chronic liver disease and cirrhosis': 151.0,
#   'Diabetes': 373.0,
#   'Diseases of Heart': 2807.0,
#   'Essential hypertension and hypertensive renal disease': 97.0,
#   'Homicide': 30.0,
#   'Influenza and pneumonia': 258.0,
#   'Kidney Disease': 252.0,
#   "Parkinson's disease": 177.0,
#   'Pneumonitis due to solids and liquids': 101.0,
#   'Septicemia': 155.0,
#   'Stroke': 620.0,
#   'Suicide': 245.0,
#   'Unintentional Injuries': 644.0},
#  'Maryland': {'All Causes': 45689.0,
#   "Alzheimer's disease": 919.0,
#   'CLRD': 2051.0,
#   'Cancer': 10609.0,
#   'Chronic liver disease and cirrhosis': 455.0,
#   'Diabetes': 1249.0,
#   'Diseases of Heart': 11244.0,
#   'Essential hypertension and hypertensive renal disease': 452.0,
#   'Homicide': 421.0,
#   'Influenza and pneumonia': 1103.0,
#   'Kidney Disease': 737.0,
#   "Parkinson's disease": 457.0,
#   'Pneumonitis due to solids and liquids': 363.0,
#   'Septicemia': 969.0,
#   'Stroke': 2315.0,
#   'Suicide': 569.0,
#   'Unintentional Injuries': 1732.0},
#  'Massachusetts': {'All Causes': 54567.0,
#   "Alzheimer's disease": 1699.0,
#   'CLRD': 2572.0,
#   'Cancer': 12858.0,
#   'Chronic liver disease and cirrhosis': 597.0,
#   'Diabetes': 1142.0,
#   'Diseases of Heart': 12023.0,
#   'Essential hypertension and hypertensive renal disease': 488.0,
#   'Homicide': 144.0,
#   'Influenza and pneumonia': 1551.0,
#   'Kidney Disease': 1261.0,
#   "Parkinson's disease": 549.0,
#   'Pneumonitis due to solids and liquids': 427.0,
#   'Septicemia': 848.0,
#   'Stroke': 2354.0,
#   'Suicide': 572.0,
#   'Unintentional Injuries': 2393.0},
#  'Michigan': {'All Causes': 92408.0,
#   "Alzheimer's disease": 3220.0,
#   'CLRD': 5539.0,
#   'Cancer': 20367.0,
#   'Chronic liver disease and cirrhosis': 1171.0,
#   'Diabetes': 2825.0,
#   'Diseases of Heart': 24156.0,
#   'Essential hypertension and hypertensive renal disease': 1034.0,
#   'Homicide': 635.0,
#   'Influenza and pneumonia': 1896.0,
#   'Kidney Disease': 1660.0,
#   "Parkinson's disease": 926.0,
#   'Pneumonitis due to solids and liquids': 554.0,
#   'Septicemia': 1215.0,
#   'Stroke': 4373.0,
#   'Suicide': 1295.0,
#   'Unintentional Injuries': 4225.0},
#  'Minnesota': {'All Causes': 40987.0,
#   "Alzheimer's disease": 1427.0,
#   'CLRD': 2287.0,
#   'Cancer': 9601.0,
#   'Chronic liver disease and cirrhosis': 517.0,
#   'Diabetes': 1163.0,
#   'Diseases of Heart': 7714.0,
#   'Essential hypertension and hypertensive renal disease': 555.0,
#   'Homicide': 131.0,
#   'Influenza and pneumonia': 751.0,
#   'Kidney Disease': 653.0,
#   "Parkinson's disease": 572.0,
#   'Pneumonitis due to solids and liquids': 255.0,
#   'Septicemia': 382.0,
#   'Stroke': 2073.0,
#   'Suicide': 678.0,
#   'Unintentional Injuries': 2405.0},
#  'Mississippi': {'All Causes': 30703.0,
#   "Alzheimer's disease": 925.0,
#   'CLRD': 1755.0,
#   'Cancer': 6527.0,
#   'Chronic liver disease and cirrhosis': 327.0,
#   'Diabetes': 1071.0,
#   'Diseases of Heart': 7715.0,
#   'Essential hypertension and hypertensive renal disease': 502.0,
#   'Homicide': 291.0,
#   'Influenza and pneumonia': 769.0,
#   'Kidney Disease': 731.0,
#   "Parkinson's disease": 204.0,
#   'Pneumonitis due to solids and liquids': 225.0,
#   'Septicemia': 674.0,
#   'Stroke': 1500.0,
#   'Suicide': 388.0,
#   'Unintentional Injuries': 1692.0},
#  'Missouri': {'All Causes': 57444.0,
#   "Alzheimer's disease": 2026.0,
#   'CLRD': 3798.0,
#   'Cancer': 12955.0,
#   'Chronic liver disease and cirrhosis': 598.0,
#   'Diabetes': 1477.0,
#   'Diseases of Heart': 14095.0,
#   'Essential hypertension and hypertensive renal disease': 442.0,
#   'Homicide': 392.0,
#   'Influenza and pneumonia': 1352.0,
#   'Kidney Disease': 1305.0,
#   "Parkinson's disease": 554.0,
#   'Pneumonitis due to solids and liquids': 578.0,
#   'Septicemia': 809.0,
#   'Stroke': 2935.0,
#   'Suicide': 960.0,
#   'Unintentional Injuries': 2981.0},
#  'Montana': {'All Causes': 9511.0,
#   "Alzheimer's disease": 267.0,
#   'CLRD': 647.0,
#   'Cancer': 1997.0,
#   'Chronic liver disease and cirrhosis': 150.0,
#   'Diabetes': 250.0,
#   'Diseases of Heart': 2004.0,
#   'Essential hypertension and hypertensive renal disease': 70.0,
#   'Homicide': 33.0,
#   'Influenza and pneumonia': 210.0,
#   'Kidney Disease': 130.0,
#   "Parkinson's disease": 101.0,
#   'Pneumonitis due to solids and liquids': 71.0,
#   'Septicemia': 110.0,
#   'Stroke': 480.0,
#   'Suicide': 243.0,
#   'Unintentional Injuries': 623.0},
#  'Nebraska': {'All Causes': 15754.0,
#   "Alzheimer's disease": 557.0,
#   'CLRD': 1032.0,
#   'Cancer': 3459.0,
#   'Chronic liver disease and cirrhosis': 181.0,
#   'Diabetes': 471.0,
#   'Diseases of Heart': 3381.0,
#   'Essential hypertension and hypertensive renal disease': 221.0,
#   'Homicide': 75.0,
#   'Influenza and pneumonia': 343.0,
#   'Kidney Disease': 222.0,
#   "Parkinson's disease": 198.0,
#   'Pneumonitis due to solids and liquids': 128.0,
#   'Septicemia': 126.0,
#   'Stroke': 820.0,
#   'Suicide': 220.0,
#   'Unintentional Injuries': 703.0},
#  'Nevada': {'All Causes': 21468.0,
#   "Alzheimer's disease": 448.0,
#   'CLRD': 1482.0,
#   'Cancer': 4817.0,
#   'Chronic liver disease and cirrhosis': 402.0,
#   'Diabetes': 424.0,
#   'Diseases of Heart': 5434.0,
#   'Essential hypertension and hypertensive renal disease': 179.0,
#   'Homicide': 151.0,
#   'Influenza and pneumonia': 513.0,
#   'Kidney Disease': 370.0,
#   "Parkinson's disease": 170.0,
#   'Pneumonitis due to solids and liquids': 159.0,
#   'Septicemia': 260.0,
#   'Stroke': 905.0,
#   'Suicide': 541.0,
#   'Unintentional Injuries': 1184.0},
#  'New Hampshire': {'All Causes': 10897.0,
#   "Alzheimer's disease": 351.0,
#   'CLRD': 668.0,
#   'Cancer': 2584.0,
#   'Chronic liver disease and cirrhosis': 147.0,
#   'Diabetes': 310.0,
#   'Diseases of Heart': 2434.0,
#   'Essential hypertension and hypertensive renal disease': 92.0,
#   'Homicide': 22.0,
#   'Influenza and pneumonia': 226.0,
#   'Kidney Disease': 175.0,
#   "Parkinson's disease": 106.0,
#   'Pneumonitis due to solids and liquids': 82.0,
#   'Septicemia': 92.0,
#   'Stroke': 441.0,
#   'Suicide': 185.0,
#   'Unintentional Injuries': 619.0},
#  'New Jersey': {'All Causes': 71403.0,
#   "Alzheimer's disease": 1812.0,
#   'CLRD': 3245.0,
#   'Cancer': 16315.0,
#   'Chronic liver disease and cirrhosis': 795.0,
#   'Diabetes': 2043.0,
#   'Diseases of Heart': 18460.0,
#   'Essential hypertension and hypertensive renal disease': 846.0,
#   'Homicide': 419.0,
#   'Influenza and pneumonia': 1356.0,
#   'Kidney Disease': 1400.0,
#   "Parkinson's disease": 703.0,
#   'Pneumonitis due to solids and liquids': 640.0,
#   'Septicemia': 1785.0,
#   'Stroke': 3456.0,
#   'Suicide': 757.0,
#   'Unintentional Injuries': 3028.0},
#  'New Mexico': {'All Causes': 16805.0,
#   "Alzheimer's disease": 339.0,
#   'CLRD': 1052.0,
#   'Cancer': 3482.0,
#   'Chronic liver disease and cirrhosis': 452.0,
#   'Diabetes': 646.0,
#   'Diseases of Heart': 3425.0,
#   'Essential hypertension and hypertensive renal disease': 169.0,
#   'Homicide': 135.0,
#   'Influenza and pneumonia': 337.0,
#   'Kidney Disease': 302.0,
#   "Parkinson's disease": 174.0,
#   'Pneumonitis due to solids and liquids': 106.0,
#   'Septicemia': 214.0,
#   'Stroke': 689.0,
#   'Suicide': 431.0,
#   'Unintentional Injuries': 1245.0},
#  'New York': {'All Causes': 150919.0,
#   "Alzheimer's disease": 2556.0,
#   'CLRD': 7110.0,
#   'Cancer': 35738.0,
#   'Chronic liver disease and cirrhosis': 1559.0,
#   'Diabetes': 4094.0,
#   'Diseases of Heart': 44039.0,
#   'Essential hypertension and hypertensive renal disease': 2269.0,
#   'Homicide': 686.0,
#   'Influenza and pneumonia': 4892.0,
#   'Kidney Disease': 2285.0,
#   "Parkinson's disease": 1208.0,
#   'Pneumonitis due to solids and liquids': 834.0,
#   'Septicemia': 2387.0,
#   'Stroke': 6176.0,
#   'Suicide': 1687.0,
#   'Unintentional Injuries': 5927.0},
#  'North Carolina': {'All Causes': 83329.0,
#   "Alzheimer's disease": 2872.0,
#   'CLRD': 4987.0,
#   'Cancer': 18589.0,
#   'Chronic liver disease and cirrhosis': 1154.0,
#   'Diabetes': 2402.0,
#   'Diseases of Heart': 17830.0,
#   'Essential hypertension and hypertensive renal disease': 856.0,
#   'Homicide': 563.0,
#   'Influenza and pneumonia': 1931.0,
#   'Kidney Disease': 1780.0,
#   "Parkinson's disease": 752.0,
#   'Pneumonitis due to solids and liquids': 687.0,
#   'Septicemia': 1484.0,
#   'Stroke': 4503.0,
#   'Suicide': 1284.0,
#   'Unintentional Injuries': 4324.0},
#  'North Dakota': {'All Causes': 6233.0,
#   "Alzheimer's disease": 363.0,
#   'CLRD': 331.0,
#   'Cancer': 1286.0,
#   'Chronic liver disease and cirrhosis': 90.0,
#   'Diabetes': 197.0,
#   'Diseases of Heart': 1382.0,
#   'Essential hypertension and hypertensive renal disease': 86.0,
#   'Homicide': 13.0,
#   'Influenza and pneumonia': 134.0,
#   'Kidney Disease': 117.0,
#   "Parkinson's disease": 59.0,
#   'Pneumonitis due to solids and liquids': 71.0,
#   'Septicemia': 72.0,
#   'Stroke': 306.0,
#   'Suicide': 128.0,
#   'Unintentional Injuries': 326.0},
#  'Ohio': {'All Causes': 113258.0,
#   "Alzheimer's disease": 3798.0,
#   'CLRD': 7007.0,
#   'Cancer': 24986.0,
#   'Chronic liver disease and cirrhosis': 1396.0,
#   'Diabetes': 3563.0,
#   'Diseases of Heart': 26878.0,
#   'Essential hypertension and hypertensive renal disease': 1317.0,
#   'Homicide': 648.0,
#   'Influenza and pneumonia': 2374.0,
#   'Kidney Disease': 1985.0,
#   "Parkinson's disease": 1088.0,
#   'Pneumonitis due to solids and liquids': 838.0,
#   'Septicemia': 1741.0,
#   'Stroke': 5690.0,
#   'Suicide': 1526.0,
#   'Unintentional Injuries': 5497.0},
#  'Oklahoma': {'All Causes': 38384.0,
#   "Alzheimer's disease": 1145.0,
#   'CLRD': 2680.0,
#   'Cancer': 8039.0,
#   'Chronic liver disease and cirrhosis': 582.0,
#   'Diabetes': 1269.0,
#   'Diseases of Heart': 9721.0,
#   'Essential hypertension and hypertensive renal disease': 396.0,
#   'Homicide': 258.0,
#   'Influenza and pneumonia': 759.0,
#   'Kidney Disease': 606.0,
#   "Parkinson's disease": 324.0,
#   'Pneumonitis due to solids and liquids': 266.0,
#   'Septicemia': 504.0,
#   'Stroke': 1880.0,
#   'Suicide': 665.0,
#   'Unintentional Injuries': 2474.0},
#  'Oregon': {'All Causes': 33939.0,
#   "Alzheimer's disease": 1312.0,
#   'CLRD': 2029.0,
#   'Cancer': 7799.0,
#   'Chronic liver disease and cirrhosis': 547.0,
#   'Diabetes': 1109.0,
#   'Diseases of Heart': 6523.0,
#   'Essential hypertension and hypertensive renal disease': 526.0,
#   'Homicide': 90.0,
#   'Influenza and pneumonia': 496.0,
#   'Kidney Disease': 327.0,
#   "Parkinson's disease": 390.0,
#   'Pneumonitis due to solids and liquids': 152.0,
#   'Septicemia': 225.0,
#   'Stroke': 1775.0,
#   'Suicide': 698.0,
#   'Unintentional Injuries': 1755.0},
#  'Pennsylvania': {'All Causes': 129123.0,
#   "Alzheimer's disease": 3271.0,
#   'CLRD': 6716.0,
#   'Cancer': 28512.0,
#   'Chronic liver disease and cirrhosis': 1265.0,
#   'Diabetes': 3804.0,
#   'Diseases of Heart': 31629.0,
#   'Essential hypertension and hypertensive renal disease': 1165.0,
#   'Homicide': 634.0,
#   'Influenza and pneumonia': 2884.0,
#   'Kidney Disease': 2767.0,
#   "Parkinson's disease": 1298.0,
#   'Pneumonitis due to solids and liquids': 1004.0,
#   'Septicemia': 2234.0,
#   'Stroke': 6604.0,
#   'Suicide': 1788.0,
#   'Unintentional Injuries': 6359.0},
#  'Rhode Island': {'All Causes': 9792.0,
#   "Alzheimer's disease": 346.0,
#   'CLRD': 476.0,
#   'Cancer': 2326.0,
#   'Chronic liver disease and cirrhosis': 124.0,
#   'Diabetes': 258.0,
#   'Diseases of Heart': 2364.0,
#   'Essential hypertension and hypertensive renal disease': 76.0,
#   'Homicide': 31.0,
#   'Influenza and pneumonia': 195.0,
#   'Kidney Disease': 149.0,
#   "Parkinson's disease": 100.0,
#   'Pneumonitis due to solids and liquids': 61.0,
#   'Septicemia': 105.0,
#   'Stroke': 397.0,
#   'Suicide': 132.0,
#   'Unintentional Injuries': 537.0},
#  'South Carolina': {'All Causes': 44582.0,
#   "Alzheimer's disease": 1623.0,
#   'CLRD': 2756.0,
#   'Cancer': 9745.0,
#   'Chronic liver disease and cirrhosis': 681.0,
#   'Diabetes': 1240.0,
#   'Diseases of Heart': 9648.0,
#   'Essential hypertension and hypertensive renal disease': 422.0,
#   'Homicide': 318.0,
#   'Influenza and pneumonia': 747.0,
#   'Kidney Disease': 869.0,
#   "Parkinson's disease": 391.0,
#   'Pneumonitis due to solids and liquids': 295.0,
#   'Septicemia': 731.0,
#   'Stroke': 2508.0,
#   'Suicide': 696.0,
#   'Unintentional Injuries': 2287.0},
#  'South Dakota': {'All Causes': 7099.0,
#   "Alzheimer's disease": 418.0,
#   'CLRD': 416.0,
#   'Cancer': 1577.0,
#   'Chronic liver disease and cirrhosis': 122.0,
#   'Diabetes': 237.0,
#   'Diseases of Heart': 1630.0,
#   'Essential hypertension and hypertensive renal disease': 74.0,
#   'Homicide': 20.0,
#   'Influenza and pneumonia': 184.0,
#   'Kidney Disease': 64.0,
#   "Parkinson's disease": 77.0,
#   'Pneumonitis due to solids and liquids': 49.0,
#   'Septicemia': 75.0,
#   'Stroke': 418.0,
#   'Suicide': 147.0,
#   'Unintentional Injuries': 425.0},
#  'Tennessee': {'All Causes': 63406.0,
#   "Alzheimer's disease": 2536.0,
#   'CLRD': 3904.0,
#   'Cancer': 13953.0,
#   'Chronic liver disease and cirrhosis': 867.0,
#   'Diabetes': 1827.0,
#   'Diseases of Heart': 14803.0,
#   'Essential hypertension and hypertensive renal disease': 688.0,
#   'Homicide': 405.0,
#   'Influenza and pneumonia': 1564.0,
#   'Kidney Disease': 1068.0,
#   "Parkinson's disease": 482.0,
#   'Pneumonitis due to solids and liquids': 555.0,
#   'Septicemia': 841.0,
#   'Stroke': 3157.0,
#   'Suicide': 1030.0,
#   'Unintentional Injuries': 3540.0},
#  'Texas': {'All Causes': 179183.0,
#   "Alzheimer's disease": 5293.0,
#   'CLRD': 9800.0,
#   'Cancer': 38412.0,
#   'Chronic liver disease and cirrhosis': 3412.0,
#   'Diabetes': 5273.0,
#   'Diseases of Heart': 40203.0,
#   'Essential hypertension and hypertensive renal disease': 1961.0,
#   'Homicide': 1354.0,
#   'Influenza and pneumonia': 3339.0,
#   'Kidney Disease': 3722.0,
#   "Parkinson's disease": 1710.0,
#   'Pneumonitis due to solids and liquids': 1274.0,
#   'Septicemia': 3892.0,
#   'Stroke': 9283.0,
#   'Suicide': 3059.0,
#   'Unintentional Injuries': 9395.0},
#  'Utah': {'All Causes': 16366.0,
#   "Alzheimer's disease": 412.0,
#   'CLRD': 718.0,
#   'Cancer': 2971.0,
#   'Chronic liver disease and cirrhosis': 193.0,
#   'Diabetes': 578.0,
#   'Diseases of Heart': 3323.0,
#   'Essential hypertension and hypertensive renal disease': 138.0,
#   'Homicide': 53.0,
#   'Influenza and pneumonia': 413.0,
#   'Kidney Disease': 312.0,
#   "Parkinson's disease": 188.0,
#   'Pneumonitis due to solids and liquids': 146.0,
#   'Septicemia': 158.0,
#   'Stroke': 836.0,
#   'Suicide': 579.0,
#   'Unintentional Injuries': 1103.0},
#  'Vermont': {'All Causes': 5639.0,
#   "Alzheimer's disease": 269.0,
#   'CLRD': 353.0,
#   'Cancer': 1318.0,
#   'Chronic liver disease and cirrhosis': 75.0,
#   'Diabetes': 139.0,
#   'Diseases of Heart': 1220.0,
#   'Essential hypertension and hypertensive renal disease': 69.0,
#   'Homicide': 10.0,
#   'Influenza and pneumonia': 77.0,
#   'Kidney Disease': 30.0,
#   "Parkinson's disease": 73.0,
#   'Pneumonitis due to solids and liquids': 36.0,
#   'Septicemia': 47.0,
#   'Stroke': 260.0,
#   'Suicide': 112.0,
#   'Unintentional Injuries': 352.0},
#  'Virginia': {'All Causes': 62716.0,
#   "Alzheimer's disease": 1642.0,
#   'CLRD': 3181.0,
#   'Cancer': 14414.0,
#   'Chronic liver disease and cirrhosis': 843.0,
#   'Diabetes': 1626.0,
#   'Diseases of Heart': 13663.0,
#   'Essential hypertension and hypertensive renal disease': 627.0,
#   'Homicide': 333.0,
#   'Influenza and pneumonia': 1442.0,
#   'Kidney Disease': 1547.0,
#   "Parkinson's disease": 551.0,
#   'Pneumonitis due to solids and liquids': 534.0,
#   'Septicemia': 1475.0,
#   'Stroke': 3287.0,
#   'Suicide': 1072.0,
#   'Unintentional Injuries': 2951.0},
#  'Washington': {'All Causes': 51264.0,
#   "Alzheimer's disease": 3277.0,
#   'CLRD': 2933.0,
#   'Cancer': 11928.0,
#   'Chronic liver disease and cirrhosis': 966.0,
#   'Diabetes': 1616.0,
#   'Diseases of Heart': 10524.0,
#   'Essential hypertension and hypertensive renal disease': 570.0,
#   'Homicide': 204.0,
#   'Influenza and pneumonia': 768.0,
#   'Kidney Disease': 461.0,
#   "Parkinson's disease": 589.0,
#   'Pneumonitis due to solids and liquids': 553.0,
#   'Septicemia': 453.0,
#   'Stroke': 2652.0,
#   'Suicide': 1027.0,
#   'Unintentional Injuries': 2826.0},
#  'West Virginia': {'All Causes': 21843.0,
#   "Alzheimer's disease": 590.0,
#   'CLRD': 1590.0,
#   'Cancer': 4718.0,
#   'Chronic liver disease and cirrhosis': 294.0,
#   'Diabetes': 841.0,
#   'Diseases of Heart': 4666.0,
#   'Essential hypertension and hypertensive renal disease': 282.0,
#   'Homicide': 74.0,
#   'Influenza and pneumonia': 481.0,
#   'Kidney Disease': 450.0,
#   "Parkinson's disease": 158.0,
#   'Pneumonitis due to solids and liquids': 119.0,
#   'Septicemia': 331.0,
#   'Stroke': 983.0,
#   'Suicide': 323.0,
#   'Unintentional Injuries': 1395.0},
#  'Wisconsin': {'All Causes': 50026.0,
#   "Alzheimer's disease": 1671.0,
#   'CLRD': 2789.0,
#   'Cancer': 11425.0,
#   'Chronic liver disease and cirrhosis': 618.0,
#   'Diabetes': 1285.0,
#   'Diseases of Heart': 11362.0,
#   'Essential hypertension and hypertensive renal disease': 427.0,
#   'Homicide': 176.0,
#   'Influenza and pneumonia': 1125.0,
#   'Kidney Disease': 993.0,
#   "Parkinson's disease": 578.0,
#   'Pneumonitis due to solids and liquids': 365.0,
#   'Septicemia': 484.0,
#   'Stroke': 2536.0,
#   'Suicide': 850.0,
#   'Unintentional Injuries': 2969.0},
#  'Wyoming': {'All Causes': 4516.0,
#   "Alzheimer's disease": 126.0,
#   'CLRD': 387.0,
#   'Cancer': 946.0,
#   'Chronic liver disease and cirrhosis': 92.0,
#   'Diabetes': 89.0,
#   'Diseases of Heart': 939.0,
#   'Essential hypertension and hypertensive renal disease': 31.0,
#   'Homicide': 17.0,
#   'Influenza and pneumonia': 112.0,
#   'Kidney Disease': 56.0,
#   "Parkinson's disease": 35.0,
#   'Pneumonitis due to solids and liquids': 27.0,
#   'Septicemia': 69.0,
#   'Stroke': 213.0,
#   'Suicide': 129.0,
#   'Unintentional Injuries': 325.0}}

# %%
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY',
}

# %%
for state in deaths_per_state:
    print(us_state_abbrev[state])
# Out:
# AL
# MI
# RI
# CO
# NE
# OK
# CA
# WY
# KY
# WA
# NH
# NJ
# MA
# NM
# IL
# LA
# WV
# OH
# ME
# MO
# VT
# MT
# SC
# ID
# KS
# NC
# FL
# HI
# TX
# ND
# GA
# NY
# UT
# MD
# AK
# MN
# PA
# IN
# MS
# DE
# AZ
# TN
# AR
# CT
# WI
# NV
# SD
# OR
# IA
# VA

# %%
states
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'United States', 'Utah', 'Vermont', 'Virginia',
#        'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'],
#       dtype=object)
